# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
channel_ids=['UC5c9VlYTSvBSCaoMu_GI6gQ','UCX8pnu3DYUnx8qy8V_c6oHg','UCMrvxKTx9hLhZcOvJkYOnAw','UCdQPeeJ0qGK6wWBiEJWcdsQ','UChXi_PlJkRMPYFQBOJ3MpxA','UCuApqv2tNQ73S7gcfrfCSDw','UCqNH56x9g4QYVpzmWTzqVYg','UC0IWRLai-BAwci_e9MylNGw','UCx6F-rETGiz7xf_vkMmX2yQ','UCgsWayzDGwj9CclwicO_R3w','UCMmMsJI54IsODpEsG08PsJA','UCU3dS5ZDA_IucoUwZ1TibIQ','UCYxMATvBqKQx7utYcYK3waA','UCNoiWmvkDUL0q-6ECxNFH0Q','UCj0sKQk9qjiIfNH22ZBWpxw','UCHpEfybj_wamBKz2u6IoiGA',
             'UCrC8mOqJQpoB7NuIMKIS6rQ','UCuWuAvEnKWez5BUr29VpwqA','UCZNNx4KYmCkwxCLdsHyWqQA','UCIl28Ab-H-3LYIPw4hhQexA','UCJKGU9G_MdI7sNjGJohFTgA','UCatL-c6pmnjzEOHSyjn-sHA','UCAuUUnT6oDeKwE6v1NGQxug','UC6nSFpj9HTCZ5t-N3Rm3-HA','UCzLqOSZPtUKrmSEnlH4LAvw','UCC552Sd-3nyi_tk2BudLUzA','UCT2OYGLtOyyui_9MGrnfyzA','UCG-KntY7aVnIGXYEBQvmBAQ','UCBqFKDipsnzvJdt6UT0lMIg','UC1gDWPG73kPaiTdat8ypvAA','UCAJRGrHzQth3r4JeJkTtLjQ','UCuOxudQSUtgikcXETRrzXCQ','UC8PICQUP0a_HsrA9S4IIgWw','UCf9_s9ii6BZ-klpgmtIi3WQ','UC7IcJI8PUf5Z3zKxnZvTBog','UCfSUSGxsZBBE3o8bCQpqYgw',
             'UCOhHO2ICt0ti9KAh-QHvttQ','UCBJycsmduvYEL83R_U4JriQ','UCXuqSBlHAE6Xw-yeJA0Tunw','UCsTcErHg8oDvUnTzoqsYeNw','UCAY_M9HyJb8oMKPV1utQQyA','UCddiUEpeqJcYeBxX1IVBKvQ','UCOmcA3f_RrH6b9NmcNa4tdg','UCMiJRAwDNSNzuYeN2uWa0pA','UCDlQwv99CovKafGvxyaiNDA','UC9fSZHEh6XsRpX-xJc6lT3A','UCR0AnNR7sViH3TWMJl5jyxw','UCXUJJNoP1QupwsYIWFXmsZg','UCEPL07qzVsOcHd3sMUws65g','UCvpfclapgcuJo0M_x65pfRw']
api_key='AIzaSyAn8K_TW_QAtNVIADKtDSgNRa68Eq3zvCc'



youtube=build('youtube','v3',developerKey=api_key)

# %% [markdown]
# ## Function to get channel statistics

# %%
def get_channel_stats(youtube,channel_ids):
    all_data=[]
    request=youtube.channels().list(
        part='snippet,contentDetails,statistics',
        id=','.join(channel_ids))
    response=request.execute()
    
    for i in range(len(response['items'])):
        data=dict(Channel_name=response['items'][i]['snippet']['title'],
              Subscribers=response['items'][i]['statistics']['subscriberCount'],
              Total_Views=response['items'][i]['statistics']['viewCount'],
              Total_Videos=response['items'][i]['statistics']['videoCount'],
              Description=response['items'][i]['snippet']['description'],
              Channel_Creation_Date=response['items'][i]['snippet']['publishedAt'],
              playlist_id=response['items'][i]['contentDetails']['relatedPlaylists']['uploads'],
              channel_id=response['items'][i]['id'])
        all_data.append(data)
        
    return all_data

# %%
get_channel_stats(youtube,channel_ids)
# Out:
# [{'Channel_name': 'Trakin Tech',
#   'Subscribers': '13100000',
#   'Total_Views': '2129740592',
#   'Total_Videos': '3528',
#   'Description': 'Trakin Tech is one of the fastest growing Youtube Channel Founded by Arun Prabhudesai that features daily videos on Smartphone & Gadget Reviews, Unboxing videos, breaking Tech Stories and Tech News.\n\nWe do not contact anyone from "@gmail.com" All our communications are from "@trak.in" email address. So please beware and do not entertain any Gmail addresses\n\nWe upload videos everyday!\n\nFor Business and Partnerships: business@trak.in\n\nThis Channel is owned, operated, and managed by, Armoks Media Private Limited.\n\nNote: Copying or Reproduction of content from this channel is strictly prohibited.\nYou can find Arun Prabhudesai on Twitter at https://twitter.com/8ap\n',
#   'Channel_Creation_Date': '2011-11-02T02:58:54Z',
#   'playlist_id': 'UUEPL07qzVsOcHd3sMUws65g',
#   'channel_id': 'UCEPL07qzVsOcHd3sMUws65g'},
# ...

# %%
channel_statistics=get_channel_stats(youtube,channel_ids)

# %%
channel_data=pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#                             Channel_name Subscribers Total_Views Total_Videos  \
# 0                            Desi Gamers    13400000  2072204259         1304
# 1                                Mythpat    13200000  2907100419          347
# 2                            AsapSCIENCE    10400000  1826024237          453
# 3                            CarryisLive    11600000  1471624763          950
# 4                       Marques Brownlee    16800000  3442707620         1535
# 5                          Unbox Therapy    18200000  4440203979         2124
# 6                                 Vsauce    18600000  2656330286          435
# 7                          Jon Rettinger     1610000   622669769         4714
# 8                              AS Gaming    19500000  2784674742         1223
# 9                                Levinho    11000000  2086862048         2027
# 10                         UrAvgConsumer     3220000   494574973         1098
# ...

# %%
channel_data['Subscribers']=pd.to_numeric(channel_data['Subscribers'])
channel_data['Total_Views']=pd.to_numeric(channel_data['Total_Views'])
channel_data['Total_Videos']=pd.to_numeric(channel_data['Total_Videos'])
#channel_data['channel_id'] = pd.to_numeric(channel_data['channel_id'])

# %%
channel_data.dtypes
# Out:
# Channel_name             object
# Subscribers               int64
# Total_Views               int64
# Total_Videos              int64
# Description              object
# Channel_Creation_Date    object
# playlist_id              object
# channel_id               object
# dtype: object

# %%
channel_data.to_csv('yt_channel.csv')

# %% [markdown]
# ## Function to get video ID

# %%
channel_data.head()
# Out:
#        Channel_name  Subscribers  Total_Views  Total_Videos  \
# 0       Desi Gamers     13400000   2072204259          1304
# 1           Mythpat     13200000   2907100419           347
# 2       AsapSCIENCE     10400000   1826024237           453
# 3       CarryisLive     11600000   1471624763           950
# 4  Marques Brownlee     16800000   3442707620          1535
#
#                                          Description Channel_Creation_Date  \
# 0  Thanks For Coming Here.\nFor Business inquiry ...  2015-05-11T05:43:04Z
# 1                                      i do timepass  2018-07-29T21:08:58Z
# 2  Making science make sense.\n\nCreated by:\n\nM...  2012-05-28T17:33:43Z
# 3  You already Know me....On this channel I do Li...  2017-01-08T13:16:13Z
# 4  MKBHD: Quality Tech Videos | YouTuber | Geek |...  2008-03-21T15:25:54Z
#
#                 playlist_id                channel_id
# 0  UUuApqv2tNQ73S7gcfrfCSDw  UCuApqv2tNQ73S7gcfrfCSDw
# ...

# %%
# Set the list of playlist IDs for the playlists you want to retrieve the video IDs for
playlist_ids = ['UUqNH56x9g4QYVpzmWTzqVYg', 'UU6nSFpj9HTCZ5t-N3Rm3-HA', 'UUR0AnNR7sViH3TWMJl5jyxw', 'UUhXi_PlJkRMPYFQBOJ3MpxA', 'UU5c9VlYTSvBSCaoMu_GI6gQ', 'UUIl28Ab-H-3LYIPw4hhQexA', 'UUBqFKDipsnzvJdt6UT0lMIg', 'UUdQPeeJ0qGK6wWBiEJWcdsQ', 'UUYxMATvBqKQx7utYcYK3waA', 'UUAJRGrHzQth3r4JeJkTtLjQ', 'UUMiJRAwDNSNzuYeN2uWa0pA', 'UUOmcA3f_RrH6b9NmcNa4tdg', 'UUEPL07qzVsOcHd3sMUws65g', 'UUuApqv2tNQ73S7gcfrfCSDw', 'UUXuqSBlHAE6Xw-yeJA0Tunw', 'UUgsWayzDGwj9CclwicO_R3w', 'UUj0sKQk9qjiIfNH22ZBWpxw', 'UUX8pnu3DYUnx8qy8V_c6oHg', 'UUrC8mOqJQpoB7NuIMKIS6rQ', 'UUG-KntY7aVnIGXYEBQvmBAQ', 'UU1gDWPG73kPaiTdat8ypvAA', 'UUuOxudQSUtgikcXETRrzXCQ', 'UUJKGU9G_MdI7sNjGJohFTgA', 'UUDlQwv99CovKafGvxyaiNDA', 'UUx6F-rETGiz7xf_vkMmX2yQ', 'UUvpfclapgcuJo0M_x65pfRw', 'UUT2OYGLtOyyui_9MGrnfyzA', 'UU9fSZHEh6XsRpX-xJc6lT3A', 'UU0IWRLai-BAwci_e9MylNGw', 'UUU3dS5ZDA_IucoUwZ1TibIQ', 'UUAuUUnT6oDeKwE6v1NGQxug', 'UUBJycsmduvYEL83R_U4JriQ', 'UUuWuAvEnKWez5BUr29VpwqA', 'UUC552Sd-3nyi_tk2BudLUzA', 'UUAY_M9HyJb8oMKPV1utQQyA', 'UUNoiWmvkDUL0q-6ECxNFH0Q', 'UU7IcJI8PUf5Z3zKxnZvTBog', 'UUXUJJNoP1QupwsYIWFXmsZg', 'UUHpEfybj_wamBKz2u6IoiGA', 'UUzLqOSZPtUKrmSEnlH4LAvw', 'UUZNNx4KYmCkwxCLdsHyWqQA', 'UUfSUSGxsZBBE3o8bCQpqYgw', 'UUddiUEpeqJcYeBxX1IVBKvQ', 'UUOhHO2ICt0ti9KAh-QHvttQ', 'UUMrvxKTx9hLhZcOvJkYOnAw', 'UUMmMsJI54IsODpEsG08PsJA', 'UUf9_s9ii6BZ-klpgmtIi3WQ', 'UUatL-c6pmnjzEOHSyjn-sHA', 'UUsTcErHg8oDvUnTzoqsYeNw', 'UU8PICQUP0a_HsrA9S4IIgWw']


# Retrieve 14 video IDs for each playlist
all_video_ids = []
for playlist_id in playlist_ids:
    next_page_token = None
    video_ids = []
    while len(video_ids) < 14:  # Exit the loop after 14 video IDs have been retrieved
        try:
            playlist_items = youtube.playlistItems().list(
                part='contentDetails',
                playlistId=playlist_id,
                maxResults=50,
                pageToken=next_page_token
            ).execute()

            # Extract the video IDs from the playlist items
            for item in playlist_items['items']:
                video_ids.append(item['contentDetails']['videoId'])
                if len(video_ids) >= 14:
                    break  # Exit the loop if 14 video IDs have been retrieved

            # Check if there are more pages of results
            next_page_token = playlist_items.get('nextPageToken')
            if not next_page_token:
                break

        except HttpError as error:
            print(f'An HTTP error {error.resp.status} occurred: {error.content}')
            break

    # Print the list of video IDs for the current playlist
    print(f'The playlist {playlist_id} contains {len(video_ids)} videos with the following IDs:')
    for video_id in video_ids:
        print(video_id)

    # Append the video IDs for the current playlist to the list of all video IDs
    all_video_ids.extend(video_ids)

# Print the list of all video IDs across all playlists
print(f'Total number of videos across all playlists: {len(all_video_ids)}')
# Out:
# The playlist UUqNH56x9g4QYVpzmWTzqVYg contains 14 videos with the following IDs:
# ot0NJIzzJYY
# 0YXU1vu_oM4
# 46rIsnHHrMM
# zliHGOfMiqk
# rojUugbfryY
# TzPDCxh-ro8
# xijNCE61O-c
# W0LpG3FMx6A
# J3sT934Foqk
# f3DAQaT_VtE
# CkobunS13Nk
# GpRtnuRRdtg
# vX5129fjFy8
# Zxhryy1L_B0
# The playlist UU6nSFpj9HTCZ5t-N3Rm3-HA contains 14 videos with the following IDs:
# 24QrPr6nBUQ
# VixkA3P-ULE
# QEKQVV371EU
# ulpbFjbZuA0
# 0aZNQ1WbR8A
# jN_I8fvUFpo
# N0eQk7hMdWg
# BMs5dcHvW4Q
# Rphsa1swMBI
# 7VYXHiLAIK4
# ZlNdLvPYhlM
# gIneEnHo54Y
# _X9FSDfG1zI
# So5uFadFegI
# The playlist UUR0AnNR7sViH3TWMJl5jyxw contains 14 videos with the following IDs:
# tXkDpsT9dZ4
# oNA5hwYvCfs
# mdwuA3ol2HQ
# JEon2xbXOE8
# 3Ml8TIceGVA
# 9ffX8eWtw_I
# a36DRU37ajY
# 3urgFLYx4Qc
# GFv4quPWDgc
# tC1BVYr1Hiw
# atRSmq8uplM
# UIEvxWtS_Po
# 25XAlWWBVaE
# y7N39x4a53U
# The playlist UUhXi_PlJkRMPYFQBOJ3MpxA contains 14 videos with the following IDs:
# ljyqVNvVTxs
# zN9HcxdfFA0
# pOiXiNcNbDI
# fnq5dFRJYus
# gtTW2XaH8dw
# ...

# %%
playlist_ids = ['UUqNH56x9g4QYVpzmWTzqVYg', 'UU6nSFpj9HTCZ5t-N3Rm3-HA', 'UUR0AnNR7sViH3TWMJl5jyxw', 'UUhXi_PlJkRMPYFQBOJ3MpxA', 'UU5c9VlYTSvBSCaoMu_GI6gQ', 'UUIl28Ab-H-3LYIPw4hhQexA', 'UUBqFKDipsnzvJdt6UT0lMIg', 'UUdQPeeJ0qGK6wWBiEJWcdsQ', 'UUYxMATvBqKQx7utYcYK3waA', 'UUAJRGrHzQth3r4JeJkTtLjQ', 'UUMiJRAwDNSNzuYeN2uWa0pA', 'UUOmcA3f_RrH6b9NmcNa4tdg', 'UUEPL07qzVsOcHd3sMUws65g', 'UUuApqv2tNQ73S7gcfrfCSDw', 'UUXuqSBlHAE6Xw-yeJA0Tunw', 'UUgsWayzDGwj9CclwicO_R3w', 'UUj0sKQk9qjiIfNH22ZBWpxw', 'UUX8pnu3DYUnx8qy8V_c6oHg', 'UUrC8mOqJQpoB7NuIMKIS6rQ', 'UUG-KntY7aVnIGXYEBQvmBAQ', 'UU1gDWPG73kPaiTdat8ypvAA', 'UUuOxudQSUtgikcXETRrzXCQ', 'UUJKGU9G_MdI7sNjGJohFTgA', 'UUDlQwv99CovKafGvxyaiNDA', 'UUx6F-rETGiz7xf_vkMmX2yQ', 'UUvpfclapgcuJo0M_x65pfRw', 'UUT2OYGLtOyyui_9MGrnfyzA', 'UU9fSZHEh6XsRpX-xJc6lT3A', 'UU0IWRLai-BAwci_e9MylNGw', 'UUU3dS5ZDA_IucoUwZ1TibIQ', 'UUAuUUnT6oDeKwE6v1NGQxug', 'UUBJycsmduvYEL83R_U4JriQ', 'UUuWuAvEnKWez5BUr29VpwqA', 'UUC552Sd-3nyi_tk2BudLUzA', 'UUAY_M9HyJb8oMKPV1utQQyA', 'UUNoiWmvkDUL0q-6ECxNFH0Q', 'UU7IcJI8PUf5Z3zKxnZvTBog', 'UUXUJJNoP1QupwsYIWFXmsZg', 'UUHpEfybj_wamBKz2u6IoiGA', 'UUzLqOSZPtUKrmSEnlH4LAvw', 'UUZNNx4KYmCkwxCLdsHyWqQA', 'UUfSUSGxsZBBE3o8bCQpqYgw', 'UUddiUEpeqJcYeBxX1IVBKvQ', 'UUOhHO2ICt0ti9KAh-QHvttQ', 'UUMrvxKTx9hLhZcOvJkYOnAw', 'UUMmMsJI54IsODpEsG08PsJA', 'UUf9_s9ii6BZ-klpgmtIi3WQ', 'UUatL-c6pmnjzEOHSyjn-sHA', 'UUsTcErHg8oDvUnTzoqsYeNw', 'UU8PICQUP0a_HsrA9S4IIgWw']

# Set the maximum number of videos to retrieve per playlist
max_results = 14

# Retrieve the video IDs for each playlist ID and append them to a list
video_ids = []
for playlist_id in playlist_ids:
    try:
        # Retrieve the playlist items for the given playlist ID
        playlist_items = youtube.playlistItems().list(
            part='contentDetails',
            playlistId=playlist_id,
            maxResults=max_results
        ).execute()

        # Extract the video IDs from the playlist items and append them to the list of video IDs
        video_ids.extend([item['contentDetails']['videoId'] for item in playlist_items['items']])

    except HttpError as error:
        print(f'An HTTP error {error.resp.status} occurred: {error.content}')
        break

# Print the list of video IDs
print(video_ids)
# Out:
# ['ot0NJIzzJYY', '0YXU1vu_oM4', '46rIsnHHrMM', 'zliHGOfMiqk', 'rojUugbfryY', 'TzPDCxh-ro8', 'xijNCE61O-c', 'W0LpG3FMx6A', 'J3sT934Foqk', 'f3DAQaT_VtE', 'CkobunS13Nk', 'GpRtnuRRdtg', 'vX5129fjFy8', 'Zxhryy1L_B0', '24QrPr6nBUQ', 'VixkA3P-ULE', 'QEKQVV371EU', 'ulpbF
3nWg', 'hb_CD-8C6ZU', 'Z8bfdHv7U1g', '5IKMtQNCLqA', 'a0IRYVmvbSI', 'iYYnpnKsj5w', 'wHiORvVuJzk', 'xUS4Eqr1QNY', 'b17A_iC-00c', 'PO3YNHpHz9c', 'vVT1JHX2g7E', 'MqXQ3GSSrR8', 'WlpLaCfqEJs', 'U41MTqJ6H7Q', 'xdz2yiU4xrI', 'vtjG9dPCf0Q', 'MWHBianlKWY', 'Qe2eTW6XPAs', 'vzyVhOm_jgg', 'F5qgSmFUbRs', 'Je69nn9W-mc', 'n8ZfuIkV18k', 'WDTTix0HMOQ', 'yoOuXuBIvm0', 'p9ZrEALc8rE', '0zcXe_5ylBg', '_jany0vm8eQ', '_f1vRC8Taes', 'OaLj_RYhzbE', 'J1opdM_tSMg', 'f7jixW87k2U', 'Uk_F-m5vmYc', 'vI3BzRecsJA', 'FyCbkcMHdIc', 'wPLfv4y9Eqw', 'jVqKWo-WgsE', 'ZOnUjfM5hc0', 'Jnk0cLVrPNU', 'lAMmq-6eS7E', 'B1gB_pRfKXc', 'FxQXrRAXpTM', 'IkAKzmSHufw', 'AWWAk128jqQ', '9zSiGKJNnNc', 'W53wBlDU1Io', 'QWXZX1LPIcw', '1l3MJZiRJmA', 'BAf9LfWIJOU', 'cVXY21HNWHA', 'DlCxnmDyLFk', '3nya0D9Go-E', 'izpvTqmoJQM', 'NmblN6McFCg', 'FpvFMwuoKlY', 'O9nkrELuS-Y', 'Jhnwxh11jcE', 'E1RW4bmQtuo', 'ubG1_oq_r9k', 'IRXWpArS5rA', 'NANLSaZ3rYM', 'PLTNGNNQvJg', 'z3pxLjuMHl0', 'Et6_RKYQsxk', 'H8vIcDOzXXk', 'Czoxsm5-OcY', 'PthW-IyLq2U', 'XvEItH88zhg', '7vi0hl_8kew', 'i1fXAmApPrA', 'FsdWCoIlyZw', 'OnGdRUgfCHg', 'Gb6RK32q4Qg', 'a6nKLiMBLgI', 'vhDfEAxBe0s', 'YbKDYTI6Gto']

# Retrieve the video details for each video ID
video_details = []
for video_id in video_ids:
    try:
        # Retrieve the video details for the given video ID
        video_response = youtube.videos().list(
            part='statistics,snippet,contentDetails',
            id=video_id
        ).execute()

        # Extract the relevant information from the video response and append it to the list of video details
        video_detail = {
            'video_id': video_id,
            'like_count': video_response['items'][0]['statistics']['likeCount'],
            'title': video_response['items'][0]['snippet']['title'],
            'description': video_response['items'][0]['snippet']['description'],
            'tags': video_response['items'][0]['snippet'].get('tags', []),
            'duration': video_response['items'][0]['contentDetails']['duration'],
            'view_count': video_response['items'][0]['statistics']['viewCount'],
            'comment_count': video_response['items'][0]['statistics']['commentCount'],
            'category_id': video_response['items'][0]['snippet']['categoryId'],
            'published_at': video_response['items'][0]['snippet']['publishedAt'],
            'channel_id' : video_response['items'][0]['snippet']['channelId'],
            'watch_time' : video_response['items'][0]['statistics']['watchTime']

        }
        video_details.append(video_detail)
        

    except HttpError as error:
        print(f'An HTTP error {error.resp.status} occurred: {error.content}')
        break

# Create a pandas DataFrame from the list of video details
df = pd.DataFrame(video_details)

# Print the DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15220/1114894391.py in <module>
#      26             'published_at': video_response['items'][0]['snippet']['publishedAt'],
#      27             'channel_id' : video_response['items'][0]['snippet']['channelId'],
# ---> 28             'watch_time' : video_response['items'][0]['statistics']['watchTime']
#      29
#      30         }
#
# KeyError: 'watchTime'

# %%
# Initialize an empty list to store the watch time results
watch_time_results = []

# Loop through all the video IDs and call the API for each video
for video_id in video_ids:
    try:
        response = youtube.videos().list(
            part='statistics',
            id=video_id
        ).execute()
    except HttpError as error:
        print(f'An HTTP error {error.resp.status} occurred: {error.content}')
        response = None

    # Extract the watch time from the video statistics and store it in the results list
    if response:
        watch_time = response['items'][0]['statistics']['watchTime']
        watch_time_results.append({
            'video_id': video_id,
            'watch_time': watch_time
        })

# Create a DataFrame from the results list
df_watch_time = pd.DataFrame(watch_time_results)
print(df_watch_time)

# %%
df.to_csv('videodatas.csv')

# %%
# create an empty list to store the values
playlist_ID = []

# iterate over each value in the playlistID column
for value in channel_data['playlist_id']:
    playlist_ID.append(value)

# print the list of values stored in a
print(playlist_ID)
print(len(playlist_ID))
# Out:
# ['UUqNH56x9g4QYVpzmWTzqVYg', 'UU6nSFpj9HTCZ5t-N3Rm3-HA', 'UUR0AnNR7sViH3TWMJl5jyxw', 'UUhXi_PlJkRMPYFQBOJ3MpxA', 'UU5c9VlYTSvBSCaoMu_GI6gQ', 'UUIl28Ab-H-3LYIPw4hhQexA', 'UUBqFKDipsnzvJdt6UT0lMIg', 'UUdQPeeJ0qGK6wWBiEJWcdsQ', 'UUYxMATvBqKQx7utYcYK3waA', 'UUAJRGrHzQth3r4JeJkTtLjQ', 'UUMiJRAwDNSNzuYeN2uWa0pA', 'UUOmcA3f_RrH6b9NmcNa4tdg', 'UUEPL07qzVsOcHd3sMUws65g', 'UUuApqv2tNQ73S7gcfrfCSDw', 'UUXuqSBlHAE6Xw-yeJA0Tunw', 'UUgsWayzDGwj9CclwicO_R3w', 'UUj0sKQk9qjiIfNH22ZBWpxw', 'UUX8pnu3DYUnx8qy8V_c6oHg', 'UUrC8mOqJQpoB7NuIMKIS6rQ', 'UUG-KntY7aVnIGXYEBQvmBAQ', 'UU1gDWPG73kPaiTdat8ypvAA', 'UUuOxudQSUtgikcXETRrzXCQ', 'UUJKGU9G_MdI7sNjGJohFTgA', 'UUDlQwv99CovKafGvxyaiNDA', 'UUx6F-rETGiz7xf_vkMmX2yQ', 'UUvpfclapgcuJo0M_x65pfRw', 'UUT2OYGLtOyyui_9MGrnfyzA', 'UU9fSZHEh6XsRpX-xJc6lT3A', 'UU0IWRLai-BAwci_e9MylNGw', 'UUU3dS5ZDA_IucoUwZ1TibIQ', 'UUAuUUnT6oDeKwE6v1NGQxug', 'UUBJycsmduvYEL83R_U4JriQ', 'UUuWuAvEnKWez5BUr29VpwqA', 'UUC552Sd-3nyi_tk2BudLUzA', 'UUAY_M9HyJb8oMKPV1utQQyA', 'UUNoiWmvkDUL0q-6
# ...
